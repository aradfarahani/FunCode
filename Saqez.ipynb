# %% [markdown]
# # Saqez

# %%
import pandas as pd
df= pd.read_csv('Saqez.csv')

# %%
df
# Out:
#           x        y     fac1     fac2     fac3     fac4
# 0    601283  3984570  1.52165  0.15672  0.12565 -0.18523
# 1    605239  3984720  1.66237 -3.89511  1.23362  0.28417
# 2    601299  3984890  0.75690  0.02076 -0.22238 -0.16700
# 3    603803  3985000  0.74488  0.05266 -0.31043  0.02684
# 4    604061  3985190  0.83567 -1.18944  0.23925  0.18571
# ..      ...      ...      ...      ...      ...      ...
# 151  590483  4001480  0.03490  0.36682 -0.67482 -0.66863
# 152  604221  4001520 -0.98828 -0.77444 -0.23344 -0.31942
# 153  590698  4001530 -0.75302 -0.74839 -0.44576 -1.01199
# 154  593374  4001660 -0.42545 -1.01841 -0.36816  0.01450
# 155  597673  4002270 -0.15521 -1.03387 -0.81635 -1.59658
#
# [156 rows x 6 columns]

# %%
x = df['x']
y = df['y']
fac1 = df['fac1']
fac2 = df['fac2']
fac3 = df['fac3']

# %%
import matplotlib.pyplot as plt
plt.scatter(df['x'], df['y'], c=df['fac1'], cmap='jet')  
plt.title('Scatter Plot of x and y Colored by Factor 1')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar(label='Factor 1')  
plt.xticks(rotation=45, fontsize='small')  
plt.yticks(rotation=45)  

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

fig, ax = plt.subplots()

ax.scatter(x, y)

center_x, center_y = 598000, 3992500  
radius = 6000 
circle = Circle((center_x, center_y), radius, color='red', fill=False)

ax.add_patch(circle)

selected_points = [(xi, yi) for xi, yi in zip(x, y) if (xi - center_x)**2 + (yi - center_y)**2 < radius**2]

selected_x, selected_y = zip(*selected_points)
ax.scatter(selected_x, selected_y, color='green')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

fig, ax = plt.subplots()

ax.scatter(x, y)

center_x = sum(x) / len(x)
center_y = sum(y) / len(y)

radius = 6000 
circle = Circle((center_x, center_y), radius, color='red', fill=False)

ax.add_patch(circle)

selected_points = [(xi, yi) for xi, yi in zip(x, y) if (xi - center_x)**2 + (yi - center_y)**2 < radius**2]

selected_x, selected_y = zip(*selected_points)
ax.scatter(selected_x, selected_y, color='green')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import numpy as np

x = np.array(x)
y = np.array(y)
points = np.column_stack((x, y))

centroid = points.mean(axis=0)
center_x, center_y = centroid

fig, ax = plt.subplots()
ax.scatter(x, y)
radius = 6000  
circle = Circle((center_x, center_y), radius, color='red', fill=False)
ax.add_patch(circle)

selected_points = [(xi, yi) for xi, yi in zip(x, y) if (xi - center_x)**2 + (yi - center_y)**2 < radius**2]

selected_x, selected_y = zip(*selected_points)
ax.scatter(selected_x, selected_y, color='green')
plt.figsize=(20,20)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

fig, ax = plt.subplots(figsize=(10, 10)) 

ax.scatter(x, y)

center_x = sum(x) / len(x)
center_y = sum(y) / len(y)
radius = 6000 
circle = Circle((center_x, center_y), radius, color='red', fill=False)

ax.add_patch(circle)

selected_points = [(xi, yi) for xi, yi in zip(x, y) if (xi - center_x)**2 + (yi - center_y)**2 < radius**2]

selected_x, selected_y = zip(*selected_points)
ax.scatter(selected_x, selected_y, color='green')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import pandas as pd

df = pd.read_csv("Saqez.csv")

center_x = df['x'].mean()
center_y = df['y'].mean()
radius = 6000 

mask = (df['x'] - center_x)**2 + (df['y'] - center_y)**2 < radius**2

selected_points = df[mask]
selected_x = selected_points['x']
selected_y = selected_points['y']
selected_fac1 = selected_points['fac1']

fig, ax = plt.subplots(figsize=(8, 8)) 

ax.scatter(df['x'], df['y'], c='lightgray')  # Plot all points in light gray
circle = Circle((center_x, center_y), radius, color='red', fill=False)
ax.add_patch(circle)

scatter = ax.scatter(selected_x, selected_y, c=selected_fac1, cmap='jet')

plt.colorbar(scatter, label='Factor 1') 
plt.title('Scatter Plot of x and y Colored by Factor 1')
plt.xlabel('x')
plt.ylabel('y')
plt.xticks(rotation=45, fontsize='small')
plt.yticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import pandas as pd

df = pd.read_csv("Saqez.csv")

center_x = df['x'].mean()
center_y = df['y'].mean()
radius = 6000  

mask = (df['x'] - center_x)**2 + (df['y'] - center_y)**2 < radius**2

selected_points = df[mask]
selected_x = selected_points['x']
selected_y = selected_points['y']
selected_fac1 = selected_points['fac1']

fig, ax = plt.subplots(figsize=(10, 10)) 

ax.scatter(df['x'], df['y'], c='lightgray') 
circle = Circle((center_x, center_y), radius, color='red', fill=False)
ax.add_patch(circle)

scatter = ax.scatter(selected_x, selected_y, c=selected_fac1, cmap='jet')

ax.set_aspect('equal', 'box')

plt.colorbar(scatter, label='Factor 1') 
plt.title('Scatter Plot of x and y Colored by Factor 1')
plt.xlabel('x')
plt.ylabel('y')
plt.xticks(rotation=45, fontsize='small')
plt.yticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import pandas as pd

df = pd.read_csv("Saqez.csv")

center_x = df['x'].mean()
center_y = df['y'].mean()
radius = 6000 

mask = (df['x'] - center_x)**2 + (df['y'] - center_y)**2 < radius**2

selected_points = df[mask]
selected_x = selected_points['x']
selected_y = selected_points['y']
selected_fac2 = selected_points['fac2']

fig, ax = plt.subplots(figsize=(10, 10)) 

ax.scatter(df['x'], df['y'], c='lightgray') 
circle = Circle((center_x, center_y), radius, color='red', fill=False)
ax.add_patch(circle)

scatter = ax.scatter(selected_x, selected_y, c=selected_fac2, cmap='jet')

ax.set_aspect('equal', 'box')

plt.colorbar(scatter, label='Factor 2') 
plt.title('Scatter Plot of x and y Colored by Factor 2')
plt.xlabel('x')
plt.ylabel('y')
plt.xticks(rotation=45, fontsize='small')
plt.yticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import pandas as pd

df = pd.read_csv("Saqez.csv")

center_x = df['x'].mean()
center_y = df['y'].mean()
radius = 6000 

mask = (df['x'] - center_x)**2 + (df['y'] - center_y)**2 < radius**2

selected_points = df[mask]
selected_x = selected_points['x']
selected_y = selected_points['y']
selected_fac3 = selected_points['fac3']

fig, ax = plt.subplots(figsize=(10, 10)) 

ax.scatter(df['x'], df['y'], c='lightgray')  # Plot all points in light gray
circle = Circle((center_x, center_y), radius, color='red', fill=False)
ax.add_patch(circle)

scatter = ax.scatter(selected_x, selected_y, c=selected_fac3, cmap='jet')

ax.set_aspect('equal', 'box')

plt.colorbar(scatter, label='Factor 3') 
plt.title('Scatter Plot of x and y Colored by Factor 3')
plt.xlabel('x')
plt.ylabel('y')
plt.xticks(rotation=45, fontsize='small')
plt.yticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import pandas as pd

df = pd.read_csv("Saqez.csv")

center_x = df['x'].mean()
center_y = df['y'].mean()
radius = 6000 

mask = (df['x'] - center_x)**2 + (df['y'] - center_y)**2 < radius**2

selected_points = df[mask]
selected_x = selected_points['x']
selected_y = selected_points['y']
selected_fac4 = selected_points['fac4']

fig, ax = plt.subplots(figsize=(10, 10)) 

ax.scatter(df['x'], df['y'], c='lightgray')  
circle = Circle((center_x, center_y), radius, color='red', fill=False)
ax.add_patch(circle)

scatter = ax.scatter(selected_x, selected_y, c=selected_fac4, cmap='jet')

ax.set_aspect('equal', 'box')

plt.colorbar(scatter, label='Factor 4')
plt.title('Scatter Plot of x and y Colored by Factor 4')
plt.xlabel('x')
plt.ylabel('y')
plt.xticks(rotation=45, fontsize='small')
plt.yticks(rotation=45)

plt.show()

# %%
new_df = selected_points.copy()

new_df = selected_points[['x', 'y', 'fac1', 'fac2','fac3','fac4']].copy()

print(new_df)
# Out:
#           x        y     fac1     fac2     fac3     fac4
# 28   596967  3987540  0.36598  1.18597 -0.08275 -0.29525
# 31   596749  3987690 -0.79451  2.11905  1.62243  1.43985
# 37   600393  3988440  0.15236 -0.00472  0.55874 -0.07918
# 38   597370  3988590 -1.25537  3.23268 -0.30454  1.10133
# 39   600219  3988590  0.76578 -0.18230  0.41695 -0.71296
# ..      ...      ...      ...      ...      ...      ...
# 115  598463  3997150  0.27655 -1.23791 -0.91353  0.46249
# 117  597851  3997820 -0.33264  0.54696 -0.83993 -0.85644
# 118  599756  3997860  0.31606 -0.87014 -0.57805  0.24153
# 123  597775  3998530 -0.49331 -0.30037 -0.64712  0.24724
# 124  598654  3998550 -0.81858 -0.47231 -0.50679 -0.86067
#
# [64 rows x 6 columns]

# %%
new_df.to_csv('selected_data.csv', index=False)

# %%
import pandas as pd
df= pd.read_csv('selected_data.csv')
df
# Out:
#          x        y     fac1     fac2     fac3     fac4
# 0   596967  3987540  0.36598  1.18597 -0.08275 -0.29525
# 1   596749  3987690 -0.79451  2.11905  1.62243  1.43985
# 2   600393  3988440  0.15236 -0.00472  0.55874 -0.07918
# 3   597370  3988590 -1.25537  3.23268 -0.30454  1.10133
# 4   600219  3988590  0.76578 -0.18230  0.41695 -0.71296
# ..     ...      ...      ...      ...      ...      ...
# 59  598463  3997150  0.27655 -1.23791 -0.91353  0.46249
# 60  597851  3997820 -0.33264  0.54696 -0.83993 -0.85644
# 61  599756  3997860  0.31606 -0.87014 -0.57805  0.24153
# 62  597775  3998530 -0.49331 -0.30037 -0.64712  0.24724
# 63  598654  3998550 -0.81858 -0.47231 -0.50679 -0.86067
#
# [64 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(df['x'], df['y'], c=df['fac1'], cmap='jet')  
plt.title('Scatter Plot of x and y Colored by Factor 1')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar(label='Factor 1')  
plt.xticks(rotation=45, fontsize='small')  
plt.yticks(rotation=45)  

plt.show()
